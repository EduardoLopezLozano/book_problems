# %% [markdown]
# ### Create a MATLAB command A(2, : ) = ... for the new row 2, to substract 3 times row 1 from the existing row 2 if the 3 by 3 matrix A is already known

# %%
'''We import the packages to use in the script'''
import random
import numpy as np
import math

# %%
'''We create our matrix 3 by 3'''
matrix = []
for j in range(3):
    vector = []
    for i in range(3):
        i = random.uniform(0, 1)
        vector.append(i)
    matrix.append(vector)
print(matrix)
# Out:
# [[0.7952054794518403, 0.2715289876655296, 0.2391910014345091], [0.8916025435420597, 0.20053239889065366, 0.4258090064746157], [0.7989352732380103, 0.5562706248509686, 0.40323189899838485]]

# %%
'''We realize the substractions of the row 1, 3 times into row 2'''
n = 3
matrix[1][0] = matrix[1][0] - n*matrix[0][0]
matrix[1][1] = matrix[1][1] - n*matrix[0][1]
matrix[1][2] = matrix[1][2] - n*matrix[0][2]

print(matrix)
# Out:
# [[0.7952054794518403, 0.2715289876655296, 0.2391910014345091], [-1.4940138948134614, -0.6140545641059351, -0.2917639978289116], [0.7989352732380103, 0.5562706248509686, 0.40323189899838485]]

# %%
'''Solution with a For loop'''
times = 3
row_substrac = 1
row = 2
for i in range(row-1):
    for j in range(row_substrac-1):
        matrix[i][j] = matrix[i][j] - times*matrix[i-1][j]
print(matrix)
# Out:
# [[0.7952054794518403, 0.2715289876655296, 0.2391910014345091], [-1.4940138948134614, -0.6140545641059351, -0.2917639978289116], [0.7989352732380103, 0.5562706248509686, 0.40323189899838485]]
